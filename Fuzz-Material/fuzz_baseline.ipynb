# %% [markdown]
# # Baseline Network Protocol Fuzzer
# This is based on GNS3. Currently we are going to implement a baseline fuzzer using random bit flips and naive oracles.
#
# ## Set the configurations and import the packages

# %%
# Global Config Setting
file_path = '/home/test/GNS3/projects/multi-router-project/multi-router-project.gns3'
capture_file_name = 'test-capture.pcap'


# Path to the pcap file
capture_file_path = "/home/test/GNS3/projects/multi-router-project/project-files/captures/" + capture_file_name

# Base configuration
BASE_URL = "http://127.0.0.1:3080"  # Adjust if GNS3 server is not localhost
AUTH_HEADER = {
    "Authorization": "Basic YWRtaW46bldCTnI5TWk3RVRqeGFocUxmQXpNTFVwV3daN0ZJbGxicnViR01LVkVVMlpiZldoeG4wajFycGRKZ0JOdVF4Yw==",
    "User-Agent": "GNS3 QT Client v2.2.49",
    "Content-Type": "application/json"
}

# %%
import json
import requests
import random
from typing import Tuple, List, Callable, Set, Any
from fuzzingbook.Fuzzer import Fuzzer
import subprocess
import re
from concurrent.futures import ThreadPoolExecutor
import time
import pyshark

# %% [markdown]
# ## Get the project id and choose the node id we are going to fuzz

# %%
def get_project_and_links(file_path):
    # Load the JSON data
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
    except FileNotFoundError:
        print(f"Error: File not found at {file_path}")
        return None, None, None
    except json.JSONDecodeError:
        print(f"Error: Failed to decode JSON from {file_path}")
        return None, None, None

    # Extract project_id
    project_id = data.get('project_id')
    if not project_id:
        print("Error: 'project_id' field not found in the JSON file.")
        return None, None, None

    # Extract nodes and links from topology
    topology = data.get('topology', {})
    nodes = topology.get('nodes', [])
    links = topology.get('links', [])

    if not nodes:
        print("Error: No nodes found in the 'topology' field of the JSON file.")
        return project_id, None, None

    # Create a mapping from node_id to node_name
    node_id_to_name = {node['node_id']: node['name'] for node in nodes if 'node_id' in node and 'name' in node}

    # Display nodes
    print(f"Project ID: {project_id}")
    print("Available Nodes:")
    node_choices = {node['name']: node['node_id'] for node in nodes if 'node_id' in node and 'name' in node}
    
    if not node_choices:
        print("No valid nodes found with both 'node_id' and 'name'.")
        return project_id, None, None

    print("\nChoose a node by its name from the list:")
    for name in node_choices.keys():
        print(f"  - {name}")

    chosen_name = input("Enter the name of the node you want to select: ").strip()
    node_id = node_choices.get(chosen_name)

    if not node_id:
        print("Invalid choice. Node name not found.")
        return project_id, None, None

    # Filter and display links for the chosen node
    print("\nAvailable Links for the selected node:")
    filtered_links = [
        link for link in links
        if any(node['node_id'] == node_id for node in link['nodes'])
    ]

    if not filtered_links:
        print("No links found for the selected node.")
        return project_id, node_id, None

    link_choices = {}
    for i, link in enumerate(filtered_links, start=1):
        # Find nodes connected to the current node via this link
        connected_nodes = [node for node in link['nodes'] if node['node_id'] != node_id]
        connected_node_names = [node_id_to_name.get(node['node_id'], "Unknown") for node in connected_nodes]
        link_name = f"Link {i} (Connected to: {', '.join(connected_node_names)})"
        link_choices[link_name] = link['link_id']
        print(f"  {i}. {link_name}")

    chosen_link = input("Enter the number of the link you want to listen to: ").strip()

    try:
        chosen_link_name = list(link_choices.keys())[int(chosen_link) - 1]
        link_id = link_choices[chosen_link_name]
    except (IndexError, ValueError):
        print("Invalid choice. Link not found.")
        return project_id, node_id, None

    return project_id, node_id, link_id

# Get the project ID, selected node, and selected link
project_id, node_id, link_id = get_project_and_links(file_path)

if project_id and node_id and link_id:
    print(f"\nSelected Project ID: {project_id}")
    print(f"Selected Node ID: {node_id}")
    print(f"Selected Link ID: {link_id}")
# Out:
# Project ID: 2e12b175-b34c-4a0b-aa74-ced42d990622
# Available Nodes:
#
# Choose a node by its name from the list:
#   - R1
#   - R2
#   - R3
#   - Switch1
#   - Switch2
#   - PC1
#   - PC2
#   - PC3
#   - PC4
# Available Links for the selected node:
#   1. Link 1 (Connected to: R2)
#   2. Link 2 (Connected to: R3)
#
# Selected Project ID: 2e12b175-b34c-4a0b-aa74-ced42d990622
# Selected Node ID: 3564d3da-e0ba-47cb-ae02-ebc7af10f11f
# Selected Link ID: 1bd01cca-4cd4-4039-b89d-edcd27ec2b5a

# %% [markdown]
# ## Start the capture of the traffic

# %%
def start_capture(project_id, link_id, capture_file_name):
    """Start packet capture on a specified link in the given project."""
    url = f"{BASE_URL}/v2/projects/{project_id}/links/{link_id}/start_capture"
    data = {
        "capture_file_name": capture_file_name,  # Specify the capture file name
        "data_link_type": "DLT_EN10MB"  # Ethernet data link type
    }

    try:
        response = requests.post(url, headers=AUTH_HEADER, json=data)

        if response.status_code == 201:
            print("Capture started successfully.")
            print("Capture details:", response.json())
        else:
            print(f"Failed to start capture. Status code: {response.status_code}")
            print("Error details:", response.text)
    except requests.exceptions.RequestException as e:
        print(f"Error during capture request: {e}")

if project_id and link_id:
    # capture_file_name = input("Enter the capture file name (e.g., capture.pcap): ").strip()
    start_capture(project_id, link_id, capture_file_name)
# Out:
# Capture started successfully.
# Capture details: {'capture_compute_id': 'vm', 'capture_file_name': 'test-capture.pcap', 'capture_file_path': '/home/test/GNS3/projects/multi-router-project/project-files/captures/test-capture.pcap', 'capturing': True, 'filters': {}, 'link_id': '1bd01cca-4cd4-4039-b89d-edcd27ec2b5a', 'link_style': {}, 'link_type': 'ethernet', 'nodes': [{'adapter_number': 0, 'label': {'rotation': 0, 'style': 'font-family: TypeWriter;font-size: 10.0;font-weight: bold;fill: #000000;fill-opacity: 1.0;', 'text': 'f0/0', 'x': 61, 'y': -6}, 'node_id': '19b50ec2-1f70-4f41-ac03-e42d237ab642', 'port_number': 0}, {'adapter_number': 0, 'label': {'rotation': 0, 'style': 'font-family: TypeWriter;font-size: 10.0;font-weight: bold;fill: #000000;fill-opacity: 1.0;', 'text': 'f0/0', 'x': 4, 'y': 50}, 'node_id': '3564d3da-e0ba-47cb-ae02-ebc7af10f11f', 'port_number': 0}], 'project_id': '2e12b175-b34c-4a0b-aa74-ced42d990622', 'suspend': False}

# %% [markdown]
# ## Design the Fuzzer Oracle to Track Errors

# %%
# Error pattern to search for
error_pattern = re.compile(r"loop", re.IGNORECASE)

def display_error_ansi(message):
    """Print an error message in red using ANSI escape codes."""
    print(f"\033[91m{message}\033[0m")


def scan_pcap_file(file_path):
    """Scan the .pcap file for packets containing the error pattern."""
    print(f"Scanning {file_path} for errors...")

    try:
        # Open the .pcap file for packet reading
        capture = pyshark.FileCapture(file_path)

        # Process packets sequentially
        for packet in capture:
            # Convert packet layers to a single string for searching
            packet_summary = str(packet)
            if error_pattern.search(packet_summary):
                display_error_ansi(f"Error found: ")
                print(f"{packet_summary}")

        # Properly close the capture
        capture.close()

    except Exception as e:
        print(f"An error occurred: {e}")

# # Main loop to scan the file periodically
# while True:
#     scan_pcap_file(capture_file_path)
#     print("Waiting for 10 seconds before next scan...\n")
#     time.sleep(10)  # Adjust the interval as needed

# %% [markdown]
# ## Baseline Random Bit Flip generating input

# %%
# Function to retrieve a configuration file
def get_config_file(node_id, config_path):
    """Retrieve a configuration file from the node."""
    url = f"{BASE_URL}/v2/projects/{project_id}/nodes/{node_id}/files/configs/{config_path}"
    response = requests.get(url, headers=AUTH_HEADER)
    if response.status_code == 200:
        print("Configuration file retrieved successfully.")
        return response.text
    else:
        print(f"Failed to retrieve configuration file. Status code: {response.status_code}")
        return None

# Function to upload a configuration file
def upload_config_file(node_id, config_path, config_data):
    """Upload a configuration file to the node."""
    url = f"{BASE_URL}/v2/projects/{project_id}/nodes/{node_id}/files/configs/{config_path}"
    headers = AUTH_HEADER.copy()
    headers["Content-Type"] = "application/octet-stream"
    response = requests.post(url, headers=headers, data=config_data)
    if response.status_code == 201:
        print("Configuration file uploaded successfully.")
    else:
        print(f"Failed to upload configuration file. Status code: {response.status_code}, Response: {response.text}")

# Mutation function
def flip_random_character(s: str) -> str:
    """Returns s with a random bit flipped in a random position."""
    if s == "":
        return s
    pos = random.randint(0, len(s) - 1)
    c = s[pos]
    bit = 1 << random.randint(0, 6)
    new_c = chr(ord(c) ^ bit)
    return s[:pos] + new_c + s[pos + 1:]

# Custom fuzzer class
class MyBaselineFuzzer(Fuzzer):
    """Base class for mutational fuzzing."""

    def __init__(self, seed: List[str], min_mutations: int = 2, max_mutations: int = 10) -> None:
        self.seed = seed
        self.min_mutations = min_mutations
        self.max_mutations = max_mutations
        self.reset()

    def reset(self) -> None:
        self.population = self.seed
        self.seed_index = 0

    def mutate(self, inp: str) -> str:
        mutators = [flip_random_character]
        mutator = random.choice(mutators)
        return mutator(inp)

    def create_candidate(self) -> str:
        candidate = random.choice(self.population)
        trials = random.randint(self.min_mutations, self.max_mutations)
        for _ in range(trials):
            candidate = self.mutate(candidate)
        return candidate

    def fuzz(self) -> str:
        if self.seed_index < len(self.seed):
            self.inp = self.seed[self.seed_index]
            self.seed_index += 1
        else:
            self.inp = self.create_candidate()
        return self.inp

# Main execution

config_path = "i1_startup-config.cfg"

# Retrieve the original configuration file
original_config = get_config_file(node_id=node_id, config_path=config_path)

if original_config:
    # Initialize the fuzzer with the original configuration as the seed
    fuzzer = MyBaselineFuzzer(seed=[original_config])

    # Generate and upload 15 mutated configurations
    for i in range(15):
        mutated_config = fuzzer.fuzz()
        print(f"\nMutated configuration {i + 1}:\n{mutated_config}\n")
        upload_config_file(node_id=node_id, config_path=config_path, config_data=mutated_config)
        scan_pcap_file(capture_file_path)
        print("Scan complete.\n")
# Out:
# Configuration file retrieved successfully.
#
# Mutated configuration 1:
# !
# !
# !
#
# !
# upgrade fpd auto
# version 15.3
# service timestamps debug datetime msec
# service timestamps log datetime msec
# no service password-encryption
# !
# hostname R1
# !
# boot-start-marker
# boot-end-marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachafle
# !!
# !
# !
# !
# !
# no ip domain lookup
# ip cef
# no ipv6 cef
# !
# multilink bund,e-name authenticated
# !
# !!
# !
# !
# !
# !
# !
# !
# !
# redundancy
# !
# !
# ip tcp synwait-time 5
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# interface FastEthernet0/0
#  ip address 10.10.10.1 255.255.255.252
#  duplexautn
#  speed auto
# !
# interface FastEthernet0/1
#  ip address 20.20.20.1 255.255.255.252
#  duplex auto
#  speed auto
# !
# router bgp 35
#  bgp router-id 3.3.3.3
#  bgp log-neighbor-changes
#  network 10.10.10.0 mask 255.255.255.252
#  network 20.20.20.0 mask 255.255.255.252
#  neighbor 10.10.10.2 remote-as 20
#  neighbor 20.20.20.2 remote-as 50
# !
# ip forwarl-protocol nd
# no ip http server
# no ip http secure-server
# !
# !
# !
# no cdp log mismatch duplex
# !
# !
# !
# control-plane
# !
# !
# mgcp behavior rsip-range tgcp-only
# mgcp behavior comedia-role none
# mgcp behavior c/media-check-media-src disable
# mgcp behavior comedia-sdp-force disable
# !
# mgcp profile default
# !
# !
# !
# gatekeeper
#  shutdown
# !
# !
# line con 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line aux 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line vty 0 4
#  login
#  transport input!all
# !
# !
# end
#
#
# Configuration file uploaded successfully.
# Scanning /home/test/GNS3/projects/multi-router-project/project-files/captures/test-capture.pcap for errors...
# An error occurred: This event loop is already running
# Scan complete.
#
#
# Mutated configuration 2:
# !
# !
# !
#
# !
# upgrade fpd auto
# version 15.3
# service timestamps debug datetime msec
# service timestamps log datetime msec
# no service password-encryption
# !
# hostname R1
# !
# boot-start-marker
# boot-end-marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachafle
# !!
# !
# !
# !
# !
# no ip domain lookup
# ip cef
# no ipv6 cef
# !
# multilink bund,e-name authenticated
# !
# !!
# !
# !
# !
# !
# !
# !
# !
# redundancy
# !
# !
# ip tcp synwait-time 5
# !
# !J!
# !
# !
# !
# !
# !
# !
# !
# interface FastEthernet0/0
#  ip address 10.10.10.1 255.255.255.252
#  duplexautn
#  speed auto
# !
# interface FastEthernet0/1
#  ip address 20.20.20.1 255.255.255.252
#  duplex auto
#  speed auto
# !
# router bgp 35
#  bgp router-id 3.3.3.3
#  bgp log-neighbor-changes
#  network 10.10.10.0 mask 255.255.255.252
#  networj 20.20.20.0 mask 255.255.255.252
#  neighbor 10.10.10.2 remote-as 20
#  neighbor 20.20.20.2 remote-as 50
# !
# ip forwarl-protocol nd
# no ip http server
# no ip http secure-server
# !
# !
# !
# no cdp log mismatch duplex
# !
# !
# !
# control-plane
# !
# !
# mgcp behavior rsip-range tgcp-olly
# mgcp behavior comedia-role none
# mgcp behavior c/media-check-media-src disable
# mgcp behavior comedia-sdp-force disable
# !
# mgcp profile dEfault
# !
# !
# !
# gatekeeper
#  shutdown
# !
# !
# line con 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line aux 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line vty 0 4
#  login
#  transport input!all
# !
# !
# end
# /tmp/ipykernel_23081/2987629983.py:29: RuntimeWarning: coroutine 'Capture._get_tshark_process' was never awaited
#   print(f"An error occurred: {e}")
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Configuration file uploaded successfully.
# Scanning /home/test/GNS3/projects/multi-router-project/project-files/captures/test-capture.pcap for errors...
# An error occurred: This event loop is already running
# Scan complete.
#
#
# Mutated configuration 3:
# !
# !
# !
#
# !
# upgrade fpd auto
# version 15.3
# service timestamps debug datetime msec
# service timestamps log datetime msec
# no service password-encryption
# !
# hostname R1
# !
# boot-start-marker
# boot-end-marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachafle
# !!
# !
# !
# !
# !
# no ip domain lookup
# ip cef
# no ipv6 cef
# !
# multilink bund,e-name authenticated
# !
# !!
# !
# !
# !
# !
# !
# !
# !
# redundancy
# !
# !
# ip tcp synwait-time$5
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# interface FastEthernet0/0
#  ip address 10.10.10.1 255.255.255.252
#  duplexautn
#  speed auto
# !
# interface FastEthernet0/1
#  ip address 20.20.20.1 255.255.255.252
#  duplex auto
#  speed auto
# !
# router bgp 35
#  bgp router-id 3.3.3.3
#  bgp log-neighbor-changes
#  network 10.10.10.0 mask 255.255.255.250
#  network 20.20.20.0 mask 255.255.255.252
#  neighbor 10.10.10.2 remote-as 20
#  neighbor 20.20.20.2 remote-as 50
# !
# ip forwarl-protocol nd
# no ip http server
# no ip http secure-sesver
# !
# !
# !
# no cdp log mismetch duplex
# !
# !
# !
# control-plane
# !
# !
# mgcp behavior rsip-range tgcp-only
# mgcp behavior comedia-role none
# mgcp behavior c/media-check-media-src disable
# mgcp behavior comedia-sdp-force disable
# !
# mgcp profile default
# !
# !
# !
# gatekeeper
#  shutdown
# !
# !
# line con 0
#  exec-timeout 0 0
#  privilege level015
#  logging synchronous
#  stopbits 1
# line aux 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line vty 0 4
#  login
#  transport input!all
# !
# !
# end
#
#
# Configuration file uploaded successfully.
# Scanning /home/test/GNS3/projects/multi-router-project/project-files/captures/test-capture.pcap for errors...
# An error occurred: This event loop is already running
# Scan complete.
#
#
# Mutated configuration 4:
# !
# !
# !
#
# !
# upgrade fpd auto
# version 15.3
# service timestamps debug datetime msec
# service timestamps log datetime msec
# no service password-encryption
# !
# hostname R1
# !
# boot-start-marker
# boot-end-marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachafle
# !!
# !
# !
# !
# !
# no ip domain lookup
# ip cef
# no ipv6 cef
# !
# multilink bund,e-name authenticated
# !
# !!
# !
# !
# !
# !
# !
# !
# !
# redundancy
# !
# !
# ip tcp synwait-time 5
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# interface FastEtherne|0/0
#  ip address 10.10.10.1 255.255.255252
#  duplexautn
#  speed auto
# !
# interface FastEthernet0/1
#  ip address 20.20.20.1 255.255.255.252
#  duplex auto
#  speed auto
# !
# router bgp 35
#  bgp router-id 3.3.3.3
#  bgp log-neighbor-changes
#  network 10.10.10.0 mask 255.255.255.252
#  network 20.20.20.0 mask 255.255.255.252
#  neighbor 10.10.10.2 remote-as 20
#  neighbor 20.20.20.2 remote-as 50
# !
# ip forwarl-protocol nd
# no ip http server
# no ip http secure-server
# !
# !
# !
# no cdp log mismatch duplex
# !
# !
# !
# control-plane
# !
# !
# mgcp behavior rsip-range tgcp-only
# mgcp behavior comedia-role none
# mgcp behavior c/media-check-media-src disable
# mgcp behavior comed)a-sdp-force disable
# !
# mgcp profile default
# !
# !
# !
# gatekeeper
#  shutdown
# !
# !
# line con 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line aux 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line vty 0 4
#  login
#  transport input!all
# !
# !
# end
#
#
# Configuration file uploaded successfully.
# Scanning /home/test/GNS3/projects/multi-router-project/project-files/captures/test-capture.pcap for errors...
# An error occurred: This event loop is already running
# Scan complete.
#
#
# Mutated configuration 5:
# !
# !
# !
#
# !
# upgrade fpd auto
# version 15.3
# service timestamps debug datetime msec*service timestamps log datetime msec
# no service password-encryption
# !
# hostname R1
# a
# boot-start-marker
# boot-end-marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachafle
# !!
# !
# !
# !
# !
# no ip domain lookup
# ip cef
# no ipv6 cef
# !
# multilink bund,e-name authenticated
# !
# !!
# !
# !
# !
# !
# !
# !
# !
# redundancy
# !
# !
# ip tcp synwait-time 5
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# interface FastEthernet0/0
#  ip address 10.10.10.1 255.255.255.252
#  duplexautn
#  speed auto
# !
# interface FastEthernet0/1
#  ip address 20.20.20.1 255.255.255.252
#  duplex auto
#  speed auto
# !
# router bgp 35
#  bgp router-)d 3.3.3.3
#  bgp log-neigibor-changes
#  network 10.10.10.0 mask 255.255.255.252
#  network 20.24.20.0 mask 255.255.255.252
#  neighbor 10.10.10.2 remote-as 20
#  neighbor 20.20.20.2 remote-as 50
# !
# ip fmrwarl-protocol nd
# no ip http server
# no ip http secure-server
# !
# a
# !
# no cdp log mismatch duplex
# !
# !
# !
# control-plane
# !
# !
# mgcp behavinr rsip-range tgcp-only
# mgcp behavior comedia-role none
# mgcp behavior c/media-check-media-src disable
# mgcp behavior comedia-sdp-force disable
# !
# mgcp profile default
# !
# !
# !
# gatekeeper
#  shutdown
# !
# !
# line con 0
#  exec-timeout 0 0
#  privilege level 15
#  logging sinchronous
#  stopbits 1
# line aux 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line vty 0 4
#  login
#  transport input!all
# !
# !
# end
#
#
# Configuration file uploaded successfully.
# Scanning /home/test/GNS3/projects/multi-router-project/project-files/captures/test-capture.pcap for errors...
# An error occurred: This event loop is already running
# Scan complete.
#
#
# Mutated configuration 6:
# !
# !
# !
#
# !
# upgrade fpd auto
# version 15.3
# service timestamps debug datetime msec
# service timestamps log datetime msec
# no serrice password-encryption
# !
# hostname R1
# !
# boot-start-marker
# boot-ent-marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachafle
# !!
# !
# !
# !!
# no ip domain lookup
# ip cef
# no ipv6 cef
# !
# multilink bund,e-name authenticated
# !
# !!
# !
# !
# !!
# !
# !
# !
# redundancy
# !
# !
# ip tcp synwait-time 5
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# interface FastEthernet0/0
#  ip address 10.10.10.1 25%.255.255.252
#  duplexautn
#  speed auto
# !
# interface FastEthernet0/1
#  ip address 20.20.20.1 255.255.255.252
#  duplex auto
#  speed auto
# !
# router bgp 35
#  bgp router-id 3.3.3.3
#  bgp log-neiwhbor-changes
#  network 10.10.10.0 mask 255.25%.255.252
#  network 20.20.20.0 mask 255.255.255.252
#  neighbor 10&10.10.2 remote-as 20
#  neighbor 20.20.20.2 remote-as 50
# !
# ip forwarl-protocol nd
# no ip http server
# no ip http secure-server
# !
# !
# !
# no cdp log mismatch duplex
# !
# !
# !
# control-plane
# !
# !
# mgcp behavior rsip-range tgcp-only
# mgcp beha~ior comedia-role none
# mgcp behavior c/media-check-media-src disable
# mgcp behavior comedia-sdp-force disable
# !
# mgcp profile default
# !
# !
# !
# gatekeeper
#  shutdown
# !
# !
# line con 0
#  exec-timeout 0 0
#  privimege level 15
#  logging synchronous
#  stopbits 1
# line aux 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line vty 0 4
#  login
#  transport input!all
# !
# !
# end
#
#
# Configuration file uploaded successfully.
# Scanning /home/test/GNS3/projects/multi-router-project/project-files/captures/test-capture.pcap for errors...
# An error occurred: This event loop is already running
# Scan complete.
#
#
# Mutated configuration 7:
# !
# !
# !
#
# !
# upgrade fpd auto
# version 15.3
# service timestamps debug datetime msec
# service timestamps log datetime msec
# no servic% password-encryption
# !
# hostname R1
# !
# boot-start-marker
# boot-end-marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachafle
# !!
# !
# !
# !
# !
# no ip domain lookup
# ip cef
# no ipv6 cef
# !
# multilink bund,e-name authenticqted
# !
# !!
# !
# !
# !
# !
# !
# !
# !
# redundancy
# !
# !
# ip tcp synwait-time 5
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# inteRface FastEthurnet0/0
#  ip address 10.10.10.1 255.255.255.252
#  duplexautn
#  speed auto
# !
# interface FastEthernet0/1
#  ip address 20.20.20.1 255.255.255.252
# "duplex auto
#  speed auto
# !
# router bgp 35
#  bgp router-id 3.3.3.3
#  bgp log-neighbor-changes
#  network 10.10.10.0 mask 255.255.255.252
#  network 20.20.20.0 mask 255.255.255.252
#  neighbor 90.10.10.2 remote-as 20
#  neighbor 20.20.20.2 remote-as 50
# !
# ip forwar,-pr/tocol nd
# no ip http server
# no ip http secure-server
# !
# !
# !
# no cdp log mismatch duplex
# !
# !
# !
# control-plane
# !
# !
# mgcp behavior rsip-range tgcp-only
# mgcp behavior comedia-role none
# mgcp behavior c/media-check-media-src diqable
# mgcp behavior comedia-sdp-force disable
# !
# mgcp profile default
# !
# !
# !
# gatekeeper
#  shutdown
# !
# !
# line con 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line aux 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line vty 0 4
#  login
#  transport input!all
# !
# !
# end
#
#
# Configuration file uploaded successfully.
# Scanning /home/test/GNS3/projects/multi-router-project/project-files/captures/test-capture.pcap for errors...
# An error occurred: This event loop is already running
# Scan complete.
#
#
# Mutated configuration 8:
# !
# !
# !
#
# !
# upgrade fpd auto
# version 15.3
# service timestamps debug datetime msec
# service timestamps log datetime msec
# no service password-encryption
# !
# hostname R1
# !
# boot-start-mabker
# boot-end-marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachafle
# !!
# !
# !
# !
# !
# no ip domain lookup
# ip cef
# no ipv6 cef
# !
# multilink bwnd,e-name authenticated
# !
# !!
# !
# !
# !
# !
# !
# !
# !
# redundancy
# !
# !
# ip tcp synwait-time 5
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# inTerface FastEthernet0/0
#  ip address 10.10.10.1 255.255.255.252
#  duplexautn
#  speed auto
# !
# interface FastEthernet0/1
#  ip address 20.20.20.1 255.255.255.252
#  duplex auto
#  speed auto
# !
# router bgp 35
#  bgp router-id 3.3.3.3
#  bgp log-neighbor-changes
#  network 10.10.10.0 mask 255.255.255.252
#  network 20.20.20.0 mask 255.255.255.252
#  neighbor 10.10.10.2 remote-as 20
#  neighbor 20.20.20.2 remote-as 50
# !
# ip forwarl-protOcol nd
# no ip http server
# no ip http secure-server
# !
# !
# !
# no cdp log mismatch duplex
# !
# !
# !
# control-plane
# !*!
# mgcp behavior rsip-range tccp-only
# mgcp bexavior comedia-role none
# mgcp behavior c/media-check-media-src disable
# mgcp behavior comedia-sdp-force disable
# !
# mgcp profile default
# !
# !
# !
# gatekeeper
#  shutdown
# !
# !
# line con 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line aux 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line vty 0 4
#  login
#  transport input!all!
# a
# end
#
#
# Configuration file uploaded successfully.
# Scanning /home/test/GNS3/projects/multi-router-project/project-files/captures/test-capture.pcap for errors...
# An error occurred: This event loop is already running
# Scan complete.
#
#
# Mutated configuration 9:
# !
# !
# !
#
# !
# upgrade fpd auto
# version 15.3
# service timestamps debug datetime msec
# service timestamps log datetime msec
# no service password-encryption
# !
# hostname R1
# !
# boot-start-marker
# boot-end-marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachafle
# !!
# !
# !
# !
# !
# no ip domain lookup
# ip cef
# no ipv6 cef
# !
# multilink bund,e-name authenticated
# !
# !!
# !
# !
# !
# !
# !
# !
# !
# redundancy
# !
# !
# ip tcp synwait-time 5
# !
# !
# !
# !
# !
# !
#
# !
# !
# !
# interface FastEthernet0/0
#  ip address 10.10.10.1 255.255.255.252
#  duplexautn
#  speed auto
# !
# interface FastEthernet0/1
#  ip address 20.20.20.1 255.255.255.252
#  duplex auto
#  speed auto
# !
# router bgp 35
#  bgp router-id 3.3.3.3
#  bgp log-neighbor-changes
#  network 10.10.10.0 mask 255.255.255.252
#  network 20.20.20.0 mask 255.255.25.252
#  neighbor 10.10.10.2 remote-as 20
#  neighbor 20.20.20.2 remote-as 50
# !
# ip forwarl-protocol nd
# no ip http server
# no ip http secure-server
# !
# !
# !
# no cdp log mismatch duplex
# !
# !
# !
# control-plane
# !
# !
# mgcp behavior rsip-range tgcp-only
# mgcp behavior comedia-role none
# mgcp `ehavior c/media-check-media-src disable
# mgcp behavior comedia-sdp-force disable
# !
# mgcp profile default
# !
# !
# !
# gatekeeper
#  shutdown
# !
# !
# line con 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line aux 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line vty 0 4
#  login
#  transport input!all
# !
# !
# end
#
#
# Configuration file uploaded successfully.
# Scanning /home/test/GNS3/projects/multi-router-project/project-files/captures/test-capture.pcap for errors...
# An error occurred: This event loop is already running
# Scan complete.
#
#
# Mutated configuration 10:
# !
# !
# !
#
# !
# upgrade fpd auto
# version`15.3
# sErvice timestamps debug datetime msec
# service timestamps log datetime msec
# no service password-encryption
# !
# hostname R1
# !
# boot-start-marker
# boot-end-marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachafle
# !!
# !
# !
# !
# !
# no ip domain lookup
# ip cef
# no ipv6 cef
# !
# multilink bund,e-name authenticated
# !
# !!
# !
# !
# !
# !
# !
# !
# !
# redundancy
# !
# !
# ip tcp synwait-time 5
# !
# !
# !!
# !
# !
# !
# !
# !
# !
# interface VastEthernet0/0
#  ip a$dress*10.10.10.1 255.255.255.252
#  duplexautn
#  speed auto
# !
# interface FastEthernet0/1
#  ip cddress 20.20.20.1 255.255.255.252
#  duplex auto
#  speed auto
# !
# router bgp 35
#  bgp router-id 3.3.3.3
#  bgp log-neighbor-changes
#  network 10.10.10.0 mask 255.255.255.252
#  network 20.20.20.0 mask 255.255.255.252
#  neighbor 10.10.10.2 remote-as 20
#  neighbor 20.20.20.2 remote-as 50
# !
# ip forwarl-protocol nd
# no yp http server
# no ip http secure-server
# !
# !
# !
# no cdp log mismatch duplex
# !
# !
# !
# control-plane
# !
# !
# mgcp behavior rsip-range tgcp-only
# mgcp behavior comedia-role none
# mgcp behavior c/media-check-media-src disable
# mggp behavior comedia-sdp-force disable
# !
# mgcp profile default
# !
# !
# !
# gatekeeper
#  shutdown
# !
# !
# line con 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line aux 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line vty 0 4
#  login
#  transport input!all
# !
# !
# end
#
#
# Configuration file uploaded successfully.
# Scanning /home/test/GNS3/projects/multi-router-project/project-files/captures/test-capture.pcap for errors...
# An error occurred: This event loop is already running
# Scan complete.
#
#
# Mutated configuration 11:
# !
# !
# !
#
# !
# upgrade fpd auto
# version 15.3
# service timestamps debug datetime msec
# service timestamps log datetime msec
# no service password-encryption
# !
# hostname R1
# !
# boot-start-marker
# boot-end-marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachafle
# !!
# !
# !
# !
# !
# no ip domain lookup
# ip cef
# no ipv6 cef
# !
# multilink bund,e-name authenticated
# !
# !!
# !
# !
# !
# !
# !
# !
# !
# redundancy
# !
# !
# ip tcp synwait-time 5
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# interface FastEthernet0/0
#  ip address 10.10.10.1 255.255.255.252
#  duplexautn
#  speed auto
# !
# interface FastEthernet0/1
#  ip address 20.20.20.1 255.255.255.252
#  duplex auto
#  speed auto
# !
# router bgp 35
#  bgp router-id 3.3.3.3
#  bgp log-neighbor-changes
#  network 10/10.10.0 mask 255.255.255.252
#  network 20.20.20.0 mask 255.255.255.252
#  neighbor 10.10.10.2 remote-as 20
#  neighbor 20.20.20.2 remote-as 50
# !
# ip forwarl-protocol nd
# no ip http server
# no ip http secure-server
# !
# !
# !
# no cdp log mismatch duplex
# !
# !
# !
# control-plane
# !
# !
# mgcp behavior rsip-range tgcp-only
# mgcp behavior comedia-role none
# mgcp behavior c/media-check-media-src disable
# mgcp behavior comedia-sdp-force disable
# !
# mgcp profile default
# !
# !
# !
# gatekeeper
#  shutdown
# !
# !
# line con 0
#  exec-timeout 0 0
#  priwilege level 15
#  logging synchronous
#  stopbits 1
# line aux 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line vty 0 4
#  login
#  transport input!all
# !
# !
# end
#
#
# Configuration file uploaded successfully.
# Scanning /home/test/GNS3/projects/multi-router-project/project-files/captures/test-capture.pcap for errors...
# An error occurred: This event loop is already running
# Scan complete.
#
#
# Mutated configuration 12:
# !
# !
# !
#
# !
# upgrade fpd auto
# version 15.3
# service timestamps debug datetime msec
# service timestamps log datetime msec
# no service password-encryption
# !
# hostname R1
# !
# boot-start-marker
# boot-end-marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachafle
# !!
# !
# !
# !
# !
# no ip domain lookup
# ip cef
# no ipv6 cef
# !
# multilink bund,e-name authenticated
# !
# !!
# !
# !
# !
# !
# !
# !
# !
# redundancy
# !
# !
# ip tcp synwait-time 5
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# interface FastEthernet0/0
#  ip address 10.10.10.1 255.255.255.252
#  duplexautn
#  speed auto
# !
# interface FastEthernet0/1
#  ip address 20.20.20.1 255.255.255.252
#  duplex auto
#  speed auto
# !
# router bgp 35
#  bgp router-id 3.3.3.3
#  bgp log-neighbor-changes
#  network 10.10.10.0 mask 255.255.255.252
#  network 20.20.20.0 mask 255.255.255.252
#  neighbor 10.10.10.2 remote-a3 20
#  neighbor 20.20.20.2 remote-as 50
# !
# ip forwarl-protocolnd
# no ip http server
# no ip http secure-server
# !
# !
# !
# no cdp log mismatch duplex
# !
# !
# !
# control-plane
# !
# !
# mgcp behavior rsip-range tgcp-only
# mgcp behavior comedia-role none
# mgcp behavior c/media-check-media-src disacle
# mgcp behavior comedia-sdp-force disable
# !
# mgcp profile default
# !
# !
# !
# gatekeeper
#  shutdown
# !
# !
# line con 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line aux 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line vty 0 4
#  login
#  transport input!all
# !
# !
# end
#
#
# Configuration file uploaded successfully.
# Scanning /home/test/GNS3/projects/multi-router-project/project-files/captures/test-capture.pcap for errors...
# An error occurred: This event loop is already running
# Scan complete.
#
#
# Mutated configuration 13:
# !
# !
# !
#
# !
# upgrade fpd auto
# version 15.3
# service timestamps debug datetime msec
# service timestamps log datetime msec
# no service password-encrypvion
# !
# hostname R1
# !
# boot-start-marker
# boot-end-marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachafle
# !!
# !
# !
# !
# !
# no ip domain lookup
# ip$cef
# no ipv6 cef
# !
# meltilink bund,e-name authenticated
# !
# !!
# !
# !
# !
# !
# !
# !
# !
# redundancy
# !
# !
# ip tcp synwait-time 5
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# interface FastEthernet0/0
#  ip address 10.10.10.1 255.255.255.252
#  duplexautn
#  speed auto
# !
# interface FastEthernet0/1
#  ip address 20.20.20.1 255.255.255.252
#  duplex auto
#  speed auto
# !
# router bgp 35
#  bgp router-id 3.3.3.3
#  bgp log-neighbor-changes
#  network 10.10.10.0 mask 255.255.255.252
#  network 20.20.20.0 mask 255.255.255.252
#  neighbor 10.10.10.2 remote-as 20
#  neighbor 20.20.20.2 remote-as 50
# !
# ip forwarl-protocol nd
# no ip http server
# no ip http secure-server
# !
# !
# !
# no cdp log mismatch duplex
# !
# !
# !
# control-plane
# !
# !
# mgcp behavior rsip-range tgcp-only
# mgsp behavior comedia-role none
# mgcp behavior c/media-check-media-src disable
# mgcp behavior comedia-sdp-force disable
# !
# mgcp profile default
# !
# !
# !
# gatekeeper
#  shutdown
# !
# !
# line con 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line aux 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line vty 0 4
#  login
#  transport input!all
# !
# !
# end
#
#
# Configuration file uploaded successfully.
# Scanning /home/test/GNS3/projects/multi-router-project/project-files/captures/test-capture.pcap for errors...
# An error occurred: This event loop is already running
# Scan complete.
#
#
# Mutated configuration 14:
# !
# !
# !
#
# !
# upgrade fpd auto
# version 15.3
# service ti-estamps debug datetime msec
# service timestamps log datetime msec
# no service password-encryption
# !
# hostname R1
# !
# boot-start-marker
# boot-end)marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachafle
# !!
# !
# !
# !
# !
# no ip d/main lookup
# ip cef
# no ipv6 sef
# !
# multilink bund,e-name authenticated
# !
# !!
# !
# !
# !
# !
# !
# !
# !
# redundancy
# !
# !
# ip tcp synwait-time 5
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# interface FastEtherndt0/0
#  ip address 10.10.10.1 255.255.255.252
#  duplexautn
#  speed auto
# !
# interface FastEthernet0/1
#  ip address 20.20.20.1 255.255.255.252
#  duplex auto
#  speed auto
# !
# router bgp 35
#  bgp router-id 3.3.3.3
#  bgp log-neighbor-changes
#  network 10.10.10.0 mask 255.255.255.252
#  network 20.20.20.0 mask 255.255.255.252
#  neighbor 10.10.10.2 remote-as 00
#  neighbor 20.20.20.2 remote-as 50
# !
# ip forwarl-protoc/l nd
# no ip http sepver
# no ip http secure-server
# !
# !
# !
# no cdp log mismatch duplex
# !
# !
# !
# control-plane
# !
# !
# mgcp behavior rsip-range tgcp-only
# mgcp behavior comedia-role none
# mgcp behavior c/media-check-media-src disable
# mgcp behavior comedia-sdp-force disable
# !
# mgcp profile default
# !
# !
# !
# gatekeeper
#  shutdown
# !
# !
# line con 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line aux 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line vty 0 4
#  login
#  transport input!all
# !
# !
# end
#
#
# Configuration file uploaded successfully.
# Scanning /home/test/GNS3/projects/multi-router-project/project-files/captures/test-capture.pcap for errors...
# An error occurred: This event loop is already running
# Scan complete.
#
#
# Mutated configuration 15:
# !
# !
# !
#
# !
# upgrade fpd auto
# version 15.3
# service timestamps debug datetime msec
# survice timestamps log datetime msec
# no service password-encryption
# !
# hostname R1
# !
# boot-start-marker
# boot-end-marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachafle
# !!
# !
# !
# !
# !
# no ip domain lookup
# ip cef
# no ipv6 cef
# !
# multilink bund,e-name authenticated
# !
# !!
# !
# !
# !
# !
# !
# !
# !
# redundancy
# !
# !
# ip tcp synwait-time 5
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# interface FastEthernet0/0
#  ip address 10.10.10.1 255.255.255.252
#  duplexautn
#  speed auto
# !
# interface FastEthernet0/1
#  ip address 20.20.20.1 255.255.255.252
#  duplex auto
#  speed auto
# !
# router bgp 35
#  bgp router-id 3.3.3.3
#  bgp log-neighbor-changes
#  network 10.10.10.0 mask 255.255.255.252
#  network 20.20n20.0 mas+ 255.655.255.252
#  neighbor 10.10.10.2 remote-as 20
#  nEighbor 20.20.20.2 remote-as 50
# !
# ip forwarl-protocol nd
# no ip http server
# no ip http secure-server
# !
# !
# !
# no cdp log mismatch duplex
# !
# !
# !
# control-plane
# !
# !
# mgct behavior rsip-range tgcp-only
# mgcp behavior comedia-rgle none
# mgcp behavior c/media-check-media-src disable
# mgcp belavior comedia-sdp-force disable
# !
# mgcp profile default
# !
# !
# !
# gatekeeper
#  shutdown
# !
# !
# line con 0
#  exec-timeout 0 0
#  privilege level 15
# `logging synchronous
#  stopbits 1
# line aux 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line vty 0 4
#  login
#  transport input!all
# !
# !
# end
#
#
# Configuration file uploaded successfully.
# Scanning /home/test/GNS3/projects/multi-router-project/project-files/captures/test-capture.pcap for errors...
# An error occurred: This event loop is already running
# Scan complete.
